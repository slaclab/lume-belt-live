# %%
import h5py
import numpy as np
import pandas as pd
import os
import datetime
import time
from make_dashboard import make_dashboard
from belt.evaluate import default_belt_merit
from belt.belt_impact import run_belt, evaluate_belt
import json
from belt.tools import NpEncoder
import matplotlib.pyplot as plt

def convertToDatedFormat(destionation_folder):
    curr_date = datetime.date.today()
    year,month,day = curr_date.strftime('%Y'),curr_date.strftime('%m'),curr_date.strftime('%d')
    destionation_folder_dated = destionation_folder + "/" + year + "/" + month + "/" + day

    if not os.path.exists(destionation_folder_dated):
        os.makedirs(destionation_folder_dated)
    
    return destionation_folder_dated

# %%
#prefix = './snapshot/2025/04/05/LCLSII-snapshot-2025-04-05T12:44:13-07:00'
#prefix = './snapshot/2025/05/17/LCLSII-snapshot-2025-05-17T10:15:01-07:00'
#prefix = './snapshot/2025/05/17/LCLSII-snapshot-2025-05-17T10:12:06-07:00'
prefix = './snapshot/2025/05/17/LCLSII-snapshot-2025-05-17T10:10:39-07:00'
#prefix = './snapshot/2025/05/17/LCLSII-snapshot-2025-05-17T09:52:23-07:00' #input_beam =  "/sdf/data/ad/ard/u/jytang/lume-belt-live/STCAV_data/particle-2025-05-17-chirped.h5.h5"

phase_shift = 1.5
input_beam =  "/sdf/data/ad/ard/u/jytang/lume-belt-live/STCAV_data/particle-2025-05-17.h5"
final_beam = "XTCAV_data/sim/LCLSII-snapshot-2025-05-17T09:52:23-07:00.h5"

with h5py.File(prefix + '.h5', 'r') as f:
    pv_dic = {}
    for key in f.keys():
        pv_dic[key] = np.array(f[key]).item()
# Out:
# /lscratch/jytang/tmp/ipykernel_647981/179844973.py:14: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   pv_dic[key] = np.array(f[key]).item()

# %%
pv_dicvb
# Out:
# {'ACCL:L0B:0100:AACTMEANSUM': 79.62382472120659,
#  'ACCL:L1B:0200:AL:BETA': -26.489104158146233,
#  'ACCL:L1B:0200:AL:CACT': -117.77097489488344,
#  'ACCL:L1B:0200:AL:CO_AMPL': 102.14311695658888,
#  'ACCL:L1B:0200:AL:EACT': 162.79159143034443,
#  'ACCL:L1B:0200:AL:NEG_AMPL': 72.90146780880521,
#  'ACCL:L1B:0200:AL:NOTA_AMPL': 53.539686765910744,
#  'ACCL:L1B:0200:AL:NOTA_PHASE': 11.309397746560757,
#  'ACCL:L1B:0200:AL:POS_AMPL': 82.31536661686954,
#  'ACCL:L1B:H100:AL:BETA': -168.6900675259798,
#  'ACCL:L1B:H100:AL:CO_AMPL': 39.895668178597795,
#  'ACCL:L1B:H100:AL:NEG_AMPL': 11.916734512006759,
#  'ACCL:L1B:H100:AL:POS_AMPL': 6.3088601229927495,
#  'ACCL:L2B:0400:AL:BETA': -10.295710358284252,
#  'ACCL:L2B:0400:AL:CACT': -243.77204311242775,
#  'ACCL:L2B:0400:AL:EACT': 1342.0160095607143,
#  'ACCL:L3B:1600:AL:BETA': 0.0,
#  'ACCL:L3B:1600:AL:CACT': -0.010464537554568665,
#  'ACCL:L3B:1600:AL:EACT': 2272.8339650374837,
#  'BEND:BC1B:200:BACT': 0.7938749011187244,
#  'BEND:BC1B:400:BACT': 0.7899741053603552,
#  'BEND:BC1B:600:BACT': 0.7899728689044198,
#  'BEND:BC1B:800:BACT': 0.7899751311992916,
#  'BEND:BC2B:200:BACT': 2.421242791031012,
#  'BEND:BC2B:500:BACT': 2.421251930518848,
#  'BEND:BC2B:600:BACT': 2.4212545754741246,
#  'BEND:BC2B:900:BACT': 2.421248643115145,
#  'BPMS:GUNB:314:TMIT': 455641728.0,
#  'PHYS:SYS0:1:SCLFB_DL_MEAS': 3794.0745329260817,
#  'PHYS:SYS0:1:SCLFB_L1B_E_MEAS': 235.08172739382888,
#  'PHYS:SYS0:1:SCLFB_L2B_E_MEAS': 1550.161314683854}

# %%
CSV = 'pv_mapping/lclsii_belt.csv'
DF = pd.read_csv(CSV)#.dropna()

PVLIST = list(DF['device_pv_name'].dropna()) 


DF
# Out:
#                   Variable                device_pv_name     pv_unit
# 0                   Charge            BPMS:GUNB:314:TMIT  n_elecrons
# 1           Initial_energy     ACCL:L0B:0100:AACTMEANSUM          MV
# 2               L1B_energy         ACCL:L1B:0200:AL:EACT          MV
# 3                 L1B_amp1      ACCL:L1B:0200:AL:CO_AMPL          MV
# 4                 L1B_amp2     ACCL:L1B:0200:AL:NEG_AMPL          MV
# 5                 L1B_amp3     ACCL:L1B:0200:AL:POS_AMPL          MV
# 6                L1B_chirp         ACCL:L1B:0200:AL:CACT          MV
# 7                L1B_phase         ACCL:L1B:0200:AL:BETA         deg
# 8             HL_amplitude    ACCL:L1B:0200:AL:NOTA_AMPL          MV
# 9                 HL_phase   ACCL:L1B:0200:AL:NOTA_PHASE         deg
# 10              HL_phase_2         ACCL:L1B:H100:AL:BETA         deg
# 11  HL_amplitude_chirponly      ACCL:L1B:H100:AL:CO_AMPL          MV
# 12       HL_amplitude_+FBK     ACCL:L1B:H100:AL:POS_AMPL          MV
# 13       HL_amplitude_-FBK     ACCL:L1B:H100:AL:NEG_AMPL          MV
# 14              L2B_energy         ACCL:L2B:0400:AL:EACT          MV
# 15               L2B_chirp         ACCL:L2B:0400:AL:CACT          MV
# 16               L2B_phase         ACCL:L2B:0400:AL:BETA         deg
# 17              L3B_energy         ACCL:L3B:1600:AL:EACT          MV
# 18               L3B_chirp         ACCL:L3B:1600:AL:CACT          MV
# 19               L3B_phase         ACCL:L3B:1600:AL:BETA         deg
# 20                   BCX11            BEND:BC1B:200:BACT        kG-m
# 21                   BCX12            BEND:BC1B:400:BACT        kG-m
# 22                   BCX13            BEND:BC1B:600:BACT        kG-m
# 23                   BCX14            BEND:BC1B:800:BACT        kG-m
# 24                   BCX21            BEND:BC2B:200:BACT        kG-m
# 25                   BCX22            BEND:BC2B:500:BACT        kG-m
# 26                   BCX23            BEND:BC2B:600:BACT        kG-m
# 27                   BCX24            BEND:BC2B:900:BACT        kG-m
# 28              BC1_energy  PHYS:SYS0:1:SCLFB_L1B_E_MEAS         MeV
# 29              BC2_energy  PHYS:SYS0:1:SCLFB_L2B_E_MEAS         MeV
# 30               DL_energy     PHYS:SYS0:1:SCLFB_DL_MEAS         MeV

# %%
df = DF[DF['device_pv_name'].notna()]
assert len(df) > 0, 'Empty dataframe!'
    
pv_names = list(df['device_pv_name'])
df['pv_value'] = [pv_dic[k] for k in pv_names]

# %%
df
# Out:
#                   Variable                device_pv_name     pv_unit  \
# 0                   Charge            BPMS:GUNB:314:TMIT  n_elecrons
# 1           Initial_energy     ACCL:L0B:0100:AACTMEANSUM          MV
# 2               L1B_energy         ACCL:L1B:0200:AL:EACT          MV
# 3                 L1B_amp1      ACCL:L1B:0200:AL:CO_AMPL          MV
# 4                 L1B_amp2     ACCL:L1B:0200:AL:NEG_AMPL          MV
# 5                 L1B_amp3     ACCL:L1B:0200:AL:POS_AMPL          MV
# 6                L1B_chirp         ACCL:L1B:0200:AL:CACT          MV
# 7                L1B_phase         ACCL:L1B:0200:AL:BETA         deg
# 8             HL_amplitude    ACCL:L1B:0200:AL:NOTA_AMPL          MV
# 9                 HL_phase   ACCL:L1B:0200:AL:NOTA_PHASE         deg
# 10              HL_phase_2         ACCL:L1B:H100:AL:BETA         deg
# 11  HL_amplitude_chirponly      ACCL:L1B:H100:AL:CO_AMPL          MV
# 12       HL_amplitude_+FBK     ACCL:L1B:H100:AL:POS_AMPL          MV
# 13       HL_amplitude_-FBK     ACCL:L1B:H100:AL:NEG_AMPL          MV
# 14              L2B_energy         ACCL:L2B:0400:AL:EACT          MV
# 15               L2B_chirp         ACCL:L2B:0400:AL:CACT          MV
# 16               L2B_phase         ACCL:L2B:0400:AL:BETA         deg
# 17              L3B_energy         ACCL:L3B:1600:AL:EACT          MV
# 18               L3B_chirp         ACCL:L3B:1600:AL:CACT          MV
# 19               L3B_phase         ACCL:L3B:1600:AL:BETA         deg
# 20                   BCX11            BEND:BC1B:200:BACT        kG-m
# 21                   BCX12            BEND:BC1B:400:BACT        kG-m
# 22                   BCX13            BEND:BC1B:600:BACT        kG-m
# 23                   BCX14            BEND:BC1B:800:BACT        kG-m
# 24                   BCX21            BEND:BC2B:200:BACT        kG-m
# 25                   BCX22            BEND:BC2B:500:BACT        kG-m
# 26                   BCX23            BEND:BC2B:600:BACT        kG-m
# 27                   BCX24            BEND:BC2B:900:BACT        kG-m
# 28              BC1_energy  PHYS:SYS0:1:SCLFB_L1B_E_MEAS         MeV
# 29              BC2_energy  PHYS:SYS0:1:SCLFB_L2B_E_MEAS         MeV
# 30               DL_energy     PHYS:SYS0:1:SCLFB_DL_MEAS         MeV
#
#         pv_value
# 0   4.556417e+08
# 1   7.962382e+01
# 2   1.627916e+02
# 3   1.021431e+02
# 4   7.290147e+01
# 5   8.231537e+01
# 6  -1.177710e+02
# 7  -2.648910e+01
# 8   5.353969e+01
# 9   1.130940e+01
# 10 -1.686901e+02
# 11  3.989567e+01
# 12  6.308860e+00
# 13  1.191673e+01
# 14  1.342016e+03
# 15 -2.437720e+02
# 16 -1.029571e+01
# 17  2.272834e+03
# 18 -1.046454e-02
# 19  0.000000e+00
# 20  7.938749e-01
# 21  7.899741e-01
# 22  7.899729e-01
# 23  7.899751e-01
# 24  2.421243e+00
# 25  2.421252e+00
# 26  2.421255e+00
# 27  2.421249e+00
# 28  2.350817e+02
# 29  1.550161e+03
# 30  3.794075e+03

# %%
settings = {"Impact_particles": final_beam}
#settings = {"Impact_particles": "/sdf/data/ad/ard/u/jytang/lume-belt-live/STCAV_data/particle-2025-05-17-chirped.h5"}

#settings = {}
#settings = {"Impact_particles": "/sdf/data/ad/ard/u/jytang/lume-belt-live/impact_particles/final_particles_50pC_12072024.h5", "num_doublings": 7}


HL_phase = df.loc[df["Variable"] == "HL_phase", 'pv_value' ].values[0] - 180
HL_amplitude = df.loc[df["Variable"] == "HL_amplitude", 'pv_value' ].values[0]*1e6
HL_gradient = HL_amplitude/5.5346304
    
L1_energy = df.loc[df["Variable"] == "L1B_energy", 'pv_value' ].values[0]
L1_chirp = df.loc[df["Variable"] == "L1B_chirp", 'pv_value' ].values[0]

L1_phase = df.loc[df["Variable"] == "L1B_phase", 'pv_value' ].values[0] 
L1_amplitude = (df.loc[df["Variable"] == "L1B_amp1", 'pv_value' ].values[0] + 
                    df.loc[df["Variable"] == "L1B_amp2", 'pv_value' ].values[0] +
                    df.loc[df["Variable"] == "L1B_amp3", 'pv_value' ].values[0])*1e6
L1_gradient = L1_amplitude/16.603888
                    
    #L1_amplitude = np.abs((L1_energy - HL_energy)/ np.cos(L1_phase/180*np.pi)*1e6/16.603888)
    #L1_amplitude = np.abs((L1_energy - HL_energy)*1e6/16.603888)



L2_energy = df.loc[df["Variable"] == "L2B_energy", 'pv_value' ].values[0]
L2_chirp = df.loc[df["Variable"] == "L2B_chirp", 'pv_value' ].values[0]

L2_phase = df.loc[df["Variable"] == "L2B_phase", 'pv_value' ].values[0]  
L2_gradient = np.abs(L2_energy/np.cos(L2_phase/180*np.pi)*1e6/99.623328)
    
    

L3_energy = df.loc[df["Variable"] == "L3B_energy", 'pv_value' ].values[0]
L3_chirp = df.loc[df["Variable"] == "L3B_chirp", 'pv_value' ].values[0]

L3_phase = df.loc[df["Variable"] == "L3B_phase", 'pv_value' ].values[0]
L3_gradient = np.abs(L3_energy/np.cos(L3_phase/180*np.pi)*1e6/166.038878)
    #L3_amplitude = np.abs(L3_energy*1e6/166.038878)
    
    
BC1_energy = df.loc[df["Variable"] == "BC1_energy", 'pv_value' ].values[0]/1e3
#BC1_energy = 0.25


#BC1_rigidity = (df.loc[df["Variable"] == "BCX11", 'pv_value' ].values[0] + df.loc[df["Variable"] == "BCX12", 'pv_value' ].values[0] +
#             df.loc[df["Variable"] == "BCX13", 'pv_value' ].values[0] + df.loc[df["Variable"] == "BCX14", 'pv_value' ].values[0])/4/10


BC1_rigidity = df.loc[df["Variable"] == "BCX11", 'pv_value' ].values[0] /10
BC1_angle = BC1_rigidity/(3.3356*BC1_energy)

BC2_energy = df.loc[df["Variable"] == "BC2_energy", 'pv_value' ].values[0]/1e3
#BC2_rigidity = (df.loc[df["Variable"] == "BCX21", 'pv_value' ].values[0] + df.loc[df["Variable"] == "BCX22", 'pv_value' ].values[0] +
#             df.loc[df["Variable"] == "BCX23", 'pv_value' ].values[0] + df.loc[df["Variable"] == "BCX24", 'pv_value' ].values[0])/4/10


BC2_rigidity = df.loc[df["Variable"] == "BCX21", 'pv_value' ].values[0]/10


BC2_angle = BC2_rigidity/(3.3356*BC2_energy)


BC1_energy_increment =BC1_energy*1e9 - (75e6 + L1_amplitude*np.cos(L1_phase/180*np.pi) +  HL_amplitude*np.cos(HL_phase/180*np.pi))
    #BC1_energy_increment =BC1_energy*1e9 - (90e6 + L1_energy*1e6 )
BC2_energy_increment = BC2_energy*1e9 - (BC1_energy*1e9 + L2_energy*1e6)

settings["BC1:angle"] = BC1_angle
settings["BC2:angle"] = BC2_angle
settings["L1:gradient"] = L1_gradient
settings["L1:phase_deg"] = L1_phase + phase_shift   #+1.15
settings["L2:gradient"] = L2_gradient 
settings["L2:phase_deg"] = L2_phase + phase_shift#+2
settings["L3:gradient"] = L3_gradient
settings["L3:phase_deg"] = L3_phase 
settings["HL:gradient"] = HL_gradient
settings["HL:phase_deg"] = HL_phase 

settings["EBC1:energy_increment"] = BC1_energy_increment
settings["EBC2:energy_increment"] = BC2_energy_increment
settings["parameters:flagfwd"] = -1

# %%
settings
# Out:
# {'Impact_particles': 'XTCAV_data/sim/LCLSII-snapshot-2025-05-17T09:52:23-07:00.h5',
#  'BC1:angle': np.float64(0.10124165435817199),
#  'BC2:angle': np.float64(0.046826045299326303),
#  'L1:gradient': np.float64(15499981.172016071),
#  'L1:phase_deg': np.float64(-24.989104158146233),
#  'L2:gradient': np.float64(13691353.60931947),
#  'L2:phase_deg': np.float64(-8.795710358284252),
#  'L3:gradient': np.float64(13688564.945840476),
#  'L3:phase_deg': np.float64(0.0),
#  'HL:gradient': np.float64(9673579.425630797),
#  'HL:phase_deg': np.float64(-168.69060225343924),
#  'EBC1:energy_increment': np.float64(-17760289.700030565),
#  'EBC2:energy_increment': np.float64(-26936422.27068901),
#  'parameters:flagfwd': -1}

# %%
BC1_angle
# Out:
# np.float64(0.10124165435817199)

# %%
BC1_angle**2*(2.44781923989 + 2/3*0.203558243263)*2
# Out:
# np.float64(0.05296159867565577)

# %%
0.04682854110733011**2*(9.86910678674+ +2/3*0.549165215621)*2
# Out:
# 0.044889865427122796

# %%
BC1_energy
# Out:
# np.float64(0.23508172739382888)

# %%
dat = {}

MODEL = 'LCLSII'
HOST = 's3df'
ARCHIVE_DIR = './scan'

SNAPSHOT_DIR = './scan'
SUMMARY_OUTPUT_DIR = './scan'
PLOT_OUTPUT_DIR = './scan'

CONFIG0 = {"input": "example/belt.in", "workdir": os.environ.get("SCRATCH")}
PREFIX = f'lume-belt-live-demo-{HOST}-{MODEL}'


DASHBOARD_KWARGS = {'outpath':PLOT_OUTPUT_DIR,            
                    'name' : PREFIX
                   }    

SNAPSHOT = None
SNAPSHOT_DIR_DATED = convertToDatedFormat(SNAPSHOT_DIR)
ARCHIVE_DIR_DATED = convertToDatedFormat(ARCHIVE_DIR)
SUMMARY_OUTPUT_DIR_DATED = convertToDatedFormat(SUMMARY_OUTPUT_DIR)

# %%
def my_merit(belt_object, itime):
    # Collect standard output statistics
    merit0 = default_belt_merit(belt_object)
    
    PLOT_OUTPUT_DIR_DATED = convertToDatedFormat(PLOT_OUTPUT_DIR)
    #Overriding at runtime to save in dated folders
    DASHBOARD_KWARGS["outpath"] = PLOT_OUTPUT_DIR_DATED
    
    # Make the dashboard from the evaluated object
    plot_file = make_dashboard(belt_object, itime=itime, **DASHBOARD_KWARGS)
    #print('Dashboard written:', plot_file)
    #logger.info(f'Dashboard written: {plot_file}')
    
    # Make all readable
    os.chmod(plot_file, 0o644)
    
    # Assign extra info
    merit0['plot_file'] = plot_file    
    merit0['isotime'] = itime
    
    # Clear any buffers
    plt.close('all')

    return merit0

# %%
settings
# Out:
# {'Impact_particles': 'XTCAV_data/sim/LCLSII-snapshot-2025-05-17T09:52:23-07:00.h5',
#  'BC1:angle': np.float64(0.10124165435817199),
#  'BC2:angle': np.float64(0.046826045299326303),
#  'L1:gradient': np.float64(15499981.172016071),
#  'L1:phase_deg': np.float64(-24.989104158146233),
#  'L2:gradient': np.float64(13691353.60931947),
#  'L2:phase_deg': np.float64(-8.795710358284252),
#  'L3:gradient': np.float64(13688564.945840476),
#  'L3:phase_deg': np.float64(0.0),
#  'HL:gradient': np.float64(9673579.425630797),
#  'HL:phase_deg': np.float64(-168.69060225343924),
#  'EBC1:energy_increment': np.float64(-17760289.700030565),
#  'EBC2:energy_increment': np.float64(-26936422.27068901),
#  'parameters:flagfwd': -1}

# %%
 # Record inputs
dat['inputs'] = settings
dat['config'] = CONFIG0
dat['pv_mapping_dataframe'] = df.to_dict()
    
itime = '2024-12-06T22:16:24-08:00'

t0 = time.time()

outputs = evaluate_belt(CONFIG0, settings,
                                       merit_f=lambda x: my_merit(x, itime),
                                       archive_path=ARCHIVE_DIR_DATED,
                                        verbose=True )
    
dat['outputs'] =  outputs   
    #logger.info(f'...finished in {(time()-t0):.1f} s')
fname = fname=f'{SUMMARY_OUTPUT_DIR_DATED}/{PREFIX}-scan-{itime}.json'

json.dump(dat, open(fname, 'w'), cls=NpEncoder)
# Out:
# Reading Impact_particles = XTCAV_data/sim/LCLSII-snapshot-2025-05-17T09:52:23-07:00.h5
# Setting BELT BC1:angle = 0.10124165435817199
# Setting BELT BC2:angle = 0.046826045299326303
# Setting BELT L1:gradient = 15499981.172016071
# Setting BELT L1:phase_deg = -24.989104158146233
# Setting BELT L2:gradient = 13691353.60931947
# Setting BELT L2:phase_deg = -8.795710358284252
# Setting BELT L3:gradient = 13688564.945840476
# Setting BELT L3:phase_deg = 0.0
# Setting BELT HL:gradient = 9673579.425630797
# Setting BELT HL:phase_deg = -168.69060225343924
# Setting BELT EBC1:energy_increment = -17760289.700030565
# Setting BELT EBC2:energy_increment = -26936422.27068901
# Setting BELT parameters:flagfwd = -1
# Configured to run in: /sdf/scratch/users/j/jytang/tmpmadm1dyr
# Running BELT in /sdf/scratch/users/j/jytang/tmpmadm1dyr
# /sdf/home/j/jytang/miniconda3/envs/lume-eblt-dev/bin/xbelt
# Updating Ek in the header to 3815015428.086623 eV
#  BELT - BEam Longitudinal Tracking (forward or backward): V1.4
#  Read input data from file - belt.in:
#  flagfwd:          -1
#  backward tracking...
#  isamp:          100
#  chglc:   7.5000000000392626E-011   0.0000000000000000        1.0000000000000000
#  total charge (C):   7.5000000000392626E-011
#  pass setting up lattice...
#  enter elment (type code):           56         -41
#  zedge:    3813.8820629180846
#  enter elment (type code):           55           0
#  zedge:    3813.8820629180846
#  enter elment (type code):           54         -41
#  zedge:    3812.8820629180846
#  enter elment (type code):           53           0
#  zedge:    3812.8820629180846
#  enter elment (type code):           52          -2
#  zedge:    3702.8820629180846
#  enter elment (type code):           51         -41
#  zedge:    3702.8820629180846
#  enter elment (type code):           50           0
#  zedge:    3702.8820629180846
#  enter elment (type code):           49         -41
#  zedge:    3701.8820629180846
#  enter elment (type code):           48           0
#  zedge:    3701.8820629180846
#  enter elment (type code):           47          -2
#  zedge:    3360.0820629180844
#  enter elment (type code):           46         -41
#  zedge:    3360.0820629180844
#  enter elment (type code):           45           0
#  zedge:    3360.0820629180844
#  enter elment (type code):           44         -41
#  zedge:    3359.0820629180844
#  enter elment (type code):           43           0
#  zedge:    3359.0820629180844
#  enter elment (type code):           42          -2
#  zedge:    2915.2820629180842
#  enter elment (type code):           41         -41
#  zedge:    2915.2820629180842
#  enter elment (type code):           40           0
#  zedge:    2915.2820629180842
#  enter elment (type code):           39         -41
#  zedge:    2914.2820629180842
#  enter elment (type code):           38           0
#  zedge:    2914.2820629180842
#  enter elment (type code):           37          -2
#  zedge:    879.08206291808426
#  enter elment (type code):           36         -41
#  zedge:    879.08206291808426
#  enter elment (type code):           35           0
#  zedge:    879.08206291808426
#  enter elment (type code):           34         -41
#  zedge:    878.08206291808426
#  enter elment (type code):           33           0
#  zedge:    878.08206291808426
#  enter elment (type code):           32          -2
#  zedge:    772.48206291808435
#  enter elment (type code):           31           0
#  zedge:    772.48206291808435
#  enter elment (type code):           30           0
#  zedge:    579.01406091808428
#  enter elment (type code):           29         -41
#  zedge:    478.82672460408423
#  enter elment (type code):           28         103
#  zedge:    478.82672460408423
#  enter elment (type code):           27         -41
#  zedge:    312.82672460408423
#  enter elment (type code):           26           0
#  zedge:    312.82672460408423
#  enter elment (type code):           25          -2
#  zedge:    278.66374816608425
#  enter elment (type code):           24           4
#  zedge:    278.66374816608425
#  enter elment (type code):           23         -39
#  zedge:    278.11458295046327
#  enter elment (type code):           22           0
#  zedge:    278.11458295046327
#  enter elment (type code):           21           0
#  zedge:    254.42970851446330
#  enter elment (type code):           20          -2
#  zedge:    200.73616494046331
#  enter elment (type code):           19         -41
#  zedge:    200.73616494046331
#  enter elment (type code):           18         103
#  zedge:    200.73616494046331
#  enter elment (type code):           17         -41
#  zedge:    101.13616494046330
#  enter elment (type code):           16           0
#  zedge:    101.13616494046330
#  enter elment (type code):           15          -2
#  zedge:    50.639004614463303
#  enter elment (type code):           14           4
#  zedge:    50.639004614463303
#  enter elment (type code):           13         -39
#  zedge:    50.435446371200300
#  enter elment (type code):           12           0
#  zedge:    50.435446371200300
#  enter elment (type code):           11           0
#  zedge:    43.179133162200301
#  enter elment (type code):           10          -2
#  zedge:    30.660516374200299
#  enter elment (type code):            9         -41
#  zedge:    30.660516374200299
#  enter elment (type code):            8         103
#  zedge:    30.660516374200299
#  enter elment (type code):            7         -41
#  zedge:    25.130516374200297
#  enter elment (type code):            6          -2
#  zedge:    25.130516374200297
#  enter elment (type code):            5           0
#  zedge:    25.130516374200297
#  enter elment (type code):            4         -41
#  zedge:    16.600000000000300
#  enter elment (type code):            3         103
#  zedge:    16.600000000000300
#  enter elment (type code):            2         -41
#  zedge:    2.9842794901924208E-013
#  enter elment (type code):            1          -2
#  zedge:    2.9842794901924208E-013
# Success - execution took 18.11s.
# <!-- lume-genesis detected Jupyter and will use HTML for rendering. -->

# %%
E = run_belt(
    settings=settings,
    belt_config=CONFIG0,
)
# Out:
# Updating Ek in the header to 3815015428.086623 eV

# %%
E.plot()

# %%
pg = E.output.particle_distributions[201].to_particlegroup()

# %%
pg['sigma_t']*1e15
# Out:
# np.float64(4892.983395753436)

# %%
pg['sigma_z']
# Out:
# np.float64(0.0014668795191661096)

# %%
E.output.plot_distribution(file_id = 109, xkey="t", ykey="energy", bins = 200)

# %%
E.output.plot_distribution(file_id = 201, xkey="t", ykey="energy", bins = 200)

# %%
settings
# Out:
# {'Impact_particles': '/sdf/data/ad/ard/u/jytang/lume-belt-live/STCAV_data/particle-2025-05-17-chirped.h5',
#  'BC1:angle': np.float64(0.10128212239543742),
#  'BC2:angle': np.float64(0.046830504089493664),
#  'L1:gradient': np.float64(15500001.134703856),
#  'L1:phase_deg': np.float64(-24.354073859471914),
#  'L2:gradient': np.float64(13688526.619733384),
#  'L2:phase_deg': np.float64(-8.793954824348303),
#  'L3:gradient': np.float64(13690835.178283634),
#  'L3:phase_deg': np.float64(0.0),
#  'HL:gradient': np.float64(9673579.278024431),
#  'HL:phase_deg': np.float64(-168.69060609599669),
#  'EBC1:energy_increment': np.float64(-19112570.0651778),
#  'EBC2:energy_increment': np.float64(-26718390.140072346)}

# %%
pg.write(final_beam)

# %%
final_beam
# Out:
# 'XTCAV_data/sim/LCLSII-snapshot-2025-05-17T09:52:23-07:00.h5'

# %%
E.input.lattice_lines
# Out:
# [WriteBeam(iwrite=102, sample=1, name='DumpLH'),
#  DriftTube(length=74.9744159418, beam_radius=0.0003, name='D1'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=41.0, switch=1.0, name='Wake1'),
#  RFCavity(length=16.6, beam_radius=0.0003, gradient=np.float64(15319065.043921089), frequency=1300000000.0, phase_deg=np.float64(-25.831063278114264), name='L1'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=41.0, switch=-1.0, name='Wake1off'),
#  DriftTube(length=8.5305163742, beam_radius=0.0003, name='D2'),
#  WriteBeam(iwrite=104, sample=1, name='DumpL1'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=42.0, switch=1.0, name='Wake2'),
#  RFCavity(length=5.53, beam_radius=0.0003, gradient=np.float64(9968950.461969564), frequency=3900000000.0, phase_deg=np.float64(-171.03313410549836), name='HL'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=42.0, switch=-1.0, name='Wake2off'),
#  WriteBeam(iwrite=106, sample=1, name='DumpHL'),
#  DriftTube(length=12.518616788, beam_radius=0.0003, name='D3'),
#  DriftTube(length=7.256313209, beam_radius=0.0003, name='D4'),
#  ChangeEnergy(energy_increment=np.float64(-11968315.387917101), name='EBC1'),
#  Chicane(length=0.203558243263, beam_radius=0.0003, drift_length=2.44781923989, angle=np.float64(0.1011897304130696), R56=2.44781923989, T566=0.0, U5666=0.0, CSR_switch=2.01, SC_switch=1.0, name='BC1'),
#  WriteBeam(iwrite=108, sample=1, name='DumpBC1'),
#  DriftTube(length=50.497160326, beam_radius=0.0002, name='D5'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=41.0, switch=1.0, name='Wake3'),
#  RFCavity(length=99.6, beam_radius=0.0002, gradient=np.float64(13258913.133834414), frequency=1300000000.0, phase_deg=np.float64(-9.805710154884395), name='L2'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=41.0, switch=-1.0, name='Wake3off'),
#  WriteBeam(iwrite=110, sample=1, name='DumpL2'),
#  DriftTube(length=53.693543574, beam_radius=0.0002, name='D6'),
#  DriftTube(length=23.684874436, beam_radius=0.0002, name='D7'),
#  ChangeEnergy(energy_increment=np.float64(-27696490.143494368), name='EBC2'),
#  Chicane(length=0.549165215621, beam_radius=0.0002, drift_length=9.86910678674, angle=np.float64(0.046816869508730284), R56=9.86910678674, T566=0.0, U5666=0.0, CSR_switch=2.01, SC_switch=1.0, name='BC2'),
#  WriteBeam(iwrite=112, sample=1, name='DumpBC2'),
#  DriftTube(length=34.162976438, beam_radius=0.0002, name='D8'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=41.0, switch=1.0, name='Wake4'),
#  RFCavity(length=166.0, beam_radius=0.0002, gradient=np.float64(13320654.343665345), frequency=1300000000.0, phase_deg=np.float64(0.0), name='L3'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=41.0, switch=-1.0, name='Wake4off'),
#  DriftTube(length=100.187336314, beam_radius=0.0002, name='D9'),
#  DriftTube(length=193.468002, beam_radius=0.0002, name='D10'),
#  WriteBeam(iwrite=114, sample=1, name='DumpL3'),
#  DriftTube(length=105.6, beam_radius=0.0002, name='EXIT_DOG'),
#  Wakefield(length=0.0, multiplier=105.6, wake_function_file_id=46.0, switch=1.0, name='wakefield1'),
#  DriftTube(length=1.0, beam_radius=1.0, name='drifttube1'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=46.0, switch=-1.0, name='wakefield2'),
#  DriftTube(length=2035.2, beam_radius=0.0002, name='BYP'),
#  Wakefield(length=0.0, multiplier=2035.2, wake_function_file_id=46.0, switch=1.0, name='wakefield3'),
#  DriftTube(length=1.0, beam_radius=1.0, name='drifttube2'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=46.0, switch=-1.0, name='wakefield4'),
#  DriftTube(length=443.8, beam_radius=0.0002, name='SPS_SLTS_BSYS'),
#  Wakefield(length=0.0, multiplier=443.8, wake_function_file_id=46.0, switch=1.0, name='wakefield5'),
#  DriftTube(length=1.0, beam_radius=1.0, name='drifttube3'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=46.0, switch=-1.0, name='wakefield6'),
#  DriftTube(length=341.8, beam_radius=0.0002, name='LTUS'),
#  Wakefield(length=0.0, multiplier=341.8, wake_function_file_id=48.0, switch=1.0, name='wakefield7'),
#  DriftTube(length=1.0, beam_radius=1.0, name='drifttube4'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=46.0, switch=-1.0, name='wakefield8'),
#  DriftTube(length=100.0, beam_radius=0.0002, name='SXR'),
#  Wakefield(length=0.0, multiplier=100.0, wake_function_file_id=47.0, switch=1.0, name='wakefield9'),
#  DriftTube(length=1.0, beam_radius=1.0, name='drifttube5'),
#  Wakefield(length=0.0, multiplier=1.0, wake_function_file_id=46.0, switch=-1.0, name='wakefield10'),
#  WriteBeam(iwrite=116, sample=1, name='DumpEne')]

# %%
E.input.parameters
# Out:
# Parameters(np=200000, nz=128, zmin=-0.002981592, zmax=0.002211398, flagfwd=1, flagdist=100, Iavg=np.float64(0.07800000000000001), Ek=74489001.04999998, mass=511005.0, charge=np.float64(6.000000000000001e-11), freq=1300000000.0)
