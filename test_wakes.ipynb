# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('./example1/rfdata42')

# %%
data
# Out:
# array([[0.0000000e+00, 7.8500000e+13, 0.0000000e+00, 0.0000000e+00],
#        [2.0000000e-06, 7.6713919e+13, 0.0000000e+00, 0.0000000e+00],
#        [4.0000000e-06, 7.5198985e+13, 0.0000000e+00, 0.0000000e+00],
#        ...,
#        [9.9940000e-03, 2.5255642e+12, 0.0000000e+00, 0.0000000e+00],
#        [9.9960000e-03, 2.5246927e+12, 0.0000000e+00, 0.0000000e+00],
#        [9.9980000e-03, 2.5238216e+12, 0.0000000e+00, 0.0000000e+00]],
#       shape=(5000, 4))

# %%
z = data[:,0]

# %%
Ez = data[:,1]

# %%
plt.plot(z, Ez)
