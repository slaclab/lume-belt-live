# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('example/rfdata46')

# %%
data
# Out:
# array([[0.0000000e+00, 5.9913866e+13, 0.0000000e+00, 0.0000000e+00],
#        [1.0000000e-07, 5.9911305e+13, 0.0000000e+00, 0.0000000e+00],
#        [2.0000000e-07, 5.9907032e+13, 0.0000000e+00, 0.0000000e+00],
#        ...,
#        [4.9970000e-04, 8.2458897e+11, 0.0000000e+00, 0.0000000e+00],
#        [4.9980000e-04, 8.2275401e+11, 0.0000000e+00, 0.0000000e+00],
#        [4.9990000e-04, 8.2091832e+11, 0.0000000e+00, 0.0000000e+00]])

# %%
z = data[:,0]

# %%
Ez = data[:,1]

# %%
plt.plot(z/3e8*1e15, Ez)
#plt.xlim([0, 0.0003])
