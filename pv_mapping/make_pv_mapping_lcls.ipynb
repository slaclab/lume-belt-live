# %%
import csv

# %%
data = [['Variable', 'device_pv_name', 'pv_unit'],

        ['Charge_inj', 'FBCK:BCI0:1:CHRGSP', 'nC'], 
        ['Charge_BC1', 'SIOC:SYS0:ML00:CALC254', 'pC'],
        ['BC1_col_left', 'COLL:LI21:235:MOTR.VAL', 'mm'],
        ['BC1_col_right', 'COLL:LI21:236:MOTR.VAL', 'mm'],
        

        #----------------L1B---------------------------------
        ['L1B_amplitude', 'ACCL:LI21:1:L1S_S_AV', 'MV'],
        ['L1B_phase', 'ACCL:LI21:1:L1S_S_PV', 'deg'],
        #['L1B_energy', 'ACCL:L1B:0200:AL:EACT', 'MV',],
        #['L1B_amp1', 'ACCL:L1B:0200:AL:CO_AMPL', 'MV'],
        #['L1B_amp2', 'ACCL:L1B:0200:AL:NEG_AMPL', 'MV'],
        #['L1B_amp3', 'ACCL:L1B:0200:AL:POS_AMPL', 'MV'],
        #['L1B_chirp', 'ACCL:L1B:0200:AL:CACT', 'MV'],
        #['L1B_phase', 'ACCL:L1B:0200:AL:BETA', 'deg'],
    
        
        #----------------L1X-----------------------------------
        ['L1X_amplitude', 'ACCL:LI21:180:L1X_S_AV', 'MV'],
        ['L1X_phase', 'ACCL:LI21:180:L1X_S_PV', 'deg'],
        #['HL_amplitude', 'ACCL:L1B:0200:AL:NOTA_AMPL', 'MV'],
        #['HL_phase', 'ACCL:L1B:0200:AL:NOTA_PHASE', 'deg'],
        #['HL_phase_2', 'ACCL:L1B:H100:AL:BETA', 'deg'],
        #['HL_amplitude_chirponly', 'ACCL:L1B:H100:AL:CO_AMPL', 'MV'],
        #['HL_amplitude_+FBK', 'ACCL:L1B:H100:AL:POS_AMPL', 'MV'],
        #['HL_amplitude_-FBK', 'ACCL:L1B:H100:AL:NEG_AMPL', 'MV'],

        
        #---------------L2-------------------------------------------
        ['L2B_amplitude', 'ACCL:LI22:1:ADES', 'MV'],
        ['L2B_phase', 'ACCL:LI22:1:PDES', 'deg'],
        
        #['L2B_energy', 'ACCL:L2B:0400:AL:EACT', 'MV'],
        #['L2B_chirp', 'ACCL:L2B:0400:AL:CACT', 'MV'],
        #['L2B_phase', 'ACCL:L2B:0400:AL:BETA', 'deg'],

        #----------------L3---------------------------------------------
        ['L3B_amplitude', 'ACCL:LI25:1:ADES', 'MV'],
        ['L3B_phase', 'ACCL:LI25:1:PDES', 'deg'],
        
        #['L3B_energy', 'ACCL:L3B:1600:AL:EACT', 'MV'],
        #['L3B_chirp', 'ACCL:L3B:1600:AL:CACT', 'MV'],
        #['L3B_phase', 'ACCL:L3B:1600:AL:BETA', 'deg'],

        #--------------BC1-----------------------------------
          
        ['BX11', 'BEND:LI21:215:BACT', 'kG-m'],
        ['BX12', 'BEND:LI21:231:BACT', 'kG-m'],
        ['BX13', 'BEND:LI21:241:BACT', 'kG-m'],
        ['BX14', 'BEND:LI21:261:BACT', 'kG-m'],
        ['BC1_current', 'BLEN:LI21:265:AIMAXCUH1H', 'A'],

        #-------------BC2-------------------------------------
        ['BX21', 'BEND:LI24:720:BACT', 'kG-m'],
        ['BX22', 'BEND:LI24:790:BACT', 'kG-m'],
        ['BX23', 'BEND:LI24:810:BACT', 'kG-m'],
        ['BX24', 'BEND:LI24:880:BACT', 'kG-m'],
        ['BC2_current', 'BLEN:LI24:886:BIMAXCUH1H', 'A'],

        #------------energy feedback?--------------------------
        #['BC1_energy', 'PHYS:SYS0:1:SCLFB_L1B_E_MEAS', 'MeV'],
        #['BC2_energy', 'PHYS:SYS0:1:SCLFB_L2B_E_MEAS', 'MeV'],
        #['DL_energy', 'PHYS:SYS0:1:SCLFB_DL_MEAS', 'MeV']
       ['DL1_energy', 'REFS:IN20:751:EDES', 'GeV'],
       ['BC1_energy', 'REFS:LI21:231:EDES', 'GeV'],
       ['BC2_energy', 'REFS:LI24:790:EDES', 'GeV']
      
       ]

# %%
with open('lcls_belt.csv', 'w', newline='') as file:

    # Create a CSV writer object
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(data[0])

    # Write the data rows
    writer.writerows(data[1:])
